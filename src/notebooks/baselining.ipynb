# %%
from datasets import load_dataset
import pandas as pd

# %%
fvapps = load_dataset("quinn-dougherty/fvapps")
# Out:
# README.md:   0%|          | 0.00/214 [00:00<?, ?B/s]
# train.jsonl:   0%|          | 0.00/162k [00:00<?, ?B/s]
# test.jsonl:   0%|          | 0.00/113k [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/40 [00:00<?, ? examples/s]

# %%
fvapps
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['apps_id', 'apps_question', 'spec', 'apps_difficulty', 'split'],
#         num_rows: 48
#     })
#     test: Dataset({
#         features: ['apps_id', 'apps_question', 'spec', 'apps_difficulty', 'split'],
#         num_rows: 40
#     })
# })

# %%
print(fvapps["train"]["spec"][0])
# Out:
# def min_coins_for_votes (voters : List (Nat × Nat)) : Nat := sorry
#
# theorem min_coins_for_votes_non_negative (voters : List (Nat × Nat)) :
#   min_coins_for_votes voters ≥ 0 := sorry
#
# theorem min_coins_for_votes_upper_bound (voters : List (Nat × Nat)) :
#   min_coins_for_votes voters ≤ List.foldl (· + ·) 0 (List.map (λ p => p.2) voters) := sorry
#
# theorem min_coins_for_votes_zero_votes (voters : List (Nat × Nat)) :
#   (∀ v ∈ voters, v.1 = 0) → min_coins_for_votes voters = 0 := sorry
#
# theorem min_coins_for_votes_single_voter (v : Nat) (c : Nat) :
#   min_coins_for_votes [(v, c)] = if v = 0 then 0 else c := sorry
#
# theorem min_coins_for_votes_unit_cost (voters : List (Nat × Nat)) :
#   (∀ v ∈ voters, v.2 = 1) →
#   min_coins_for_votes voters ≤ List.length voters ∧
#   min_coins_for_votes voters ≤ List.foldl Nat.max 0 (List.map (λ p => p.1) voters) := sorry
#
# theorem min_coins_for_votes_sorted_input (voters : List (Nat × Nat)) :
# ...

# %%
pd.DataFrame(fvapps["train"])
# Out:
#    apps_id                                      apps_question  \
# 0     0023  The only difference between easy and hard vers...
# 1     0044  Today the kindergarten has a new group of $n$ ...
# 2     0033  Numbers $1, 2, 3, \dots n$ (each integer from ...
# 3     0014  Vasya claims that he had a paper square. He cu...
# 4     0031  Skier rides on a snowy field. Its movements ca...
# 5     0015  Screen resolution of Polycarp's monitor is $a ...
# 6     0005  The sequence of $m$ integers is called the per...
# 7     0046  Recently, you found a bot to play "Rock paper ...
# 8     0002  You are given three sequences: $a_1, a_2, \ldo...
# 9     0011  You have a string $s$ — a sequence of commands...
# 10    0016  Polycarp, Arkady's friend, prepares to the pro...
# 11    0036  It is lunch time for Mole. His friend, Marmot,...
# 12    0028  Acacius is studying strings theory. Today he c...
# 13    0042  You are given a binary string $s$ (recall that...
# ...
