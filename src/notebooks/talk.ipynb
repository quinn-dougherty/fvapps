# %%
import datasets
import pandas as pd

# %%
fvapps = datasets.load_dataset("quinn-dougherty/fvapps", split="train")
df = pd.DataFrame(fvapps)

# %%
df
# Out:
#      apps_id                                      apps_question  \
# 0       2459  Given an integer, write an algorithm to conver...
# 1       4172  Given a string, return the minimal number of p...
# 2       2565  =====Function Descriptions=====\nIn Python, a ...
# 3       3430  You were given a string of integer temperature...
# 4       1804  There is a secret string which is unknown to y...
# ...      ...                                                ...
# 4707    4067  Bob is preparing to pass IQ test. The most fre...
# 4708    2688  # Task\n let F(N) be the sum square of digits ...
# 4709    3101  Given a list of unique words. Find all pairs o...
# 4710    3866  Three candidates take part in a TV show.\n\nIn...
# 4711    1128  The Chef is given an array of numbers and aske...
#
#                                                    spec  sorries  \
# 0     def to_hex (n : Int) : String := sorry\n\n/-- ...        6
# ...

# %%
sample = df.sample(1)
sample
# Out:
#      apps_id                                      apps_question  \
# 2116    2047  Allen dreams of one day owning a enormous flee...
#
#                                                    spec  sorries  \
# 2116  def solve_parking (n k : Nat) (grid : List (Li...        3
#
#      apps_difficulty  split
# 2116     competition  train

# %%
print(sample.apps_question.values[0])
# Out:
# Allen dreams of one day owning a enormous fleet of electric cars, the car of the future! He knows that this will give him a big status boost. As Allen is planning out all of the different types of cars he will own and how he will arrange them, he realizes that he has a problem.
#
# Allen's future parking lot can be represented as a rectangle with $4$ rows and $n$ ($n \le 50$) columns of rectangular spaces, each of which can contain at most one car at any time. He imagines having $k$ ($k \le 2n$) cars in the grid, and all the cars are initially in the second and third rows. Each of the cars also has a different designated parking space in the first or fourth row. Allen has to put the cars into corresponding parking places.
#
#  [Image] Illustration to the first example.
#
# ...

# %%
print(sample.spec.values[0])
# Out:
# def solve_parking (n k : Nat) (grid : List (List Nat)) : List Nat :=
# sorry
#
# theorem parking_properties (n k : Nat)
#   (h1 : 1 ≤ n ∧ n ≤ 10)
#   (h2 : 1 ≤ k ∧ k ≤ 20)
#   (grid : List (List Nat))
#   (h3 : grid.length = 4)
#   (h4 : ∀ row ∈ grid, row.length = n) :
#   let result := solve_parking n k grid;
#   -- Result is a list
#   result.length > 0
#   -- First element is non-negative
#   ∧ result.head?.isSome
#   ∧ (∀ h, result.head?.get h ≥ 0)
#   -- If solution exists (head ≠ 1), then rest of list represents valid moves
#   ∧ (∀ h, result.head?.get h ≠ 1 →
#       -- Number of moves matches head
#       result.tail.length = result.head?.get h
#       -- Moves are valid format
#       ∧ ∀ move ∈ result.tail,
#           -- Car number in valid range
#           0 ≤ move ∧ move ≤ k
#           -- Row in valid range
#           ∧ 1 ≤ move ∧ move ≤ 4
#           -- Column in valid range
#           ∧ 1 ≤ move ∧ move ≤ n
#       -- Solution has finite moves
# ...

# %% [markdown]
# # Sample 23

# %%
twentythree = df[df.apps_id == "0023"]

# %%
print(twentythree.apps_question.values[0])
# Out:
# The only difference between easy and hard versions is constraints.
#
# Now elections are held in Berland and you want to win them. More precisely, you want everyone to vote for you.
#
# There are $n$ voters, and two ways to convince each of them to vote for you. The first way to convince the $i$-th voter is to pay him $p_i$ coins. The second way is to make $m_i$ other voters vote for you, and the $i$-th voter will vote for free.
#
# Moreover, the process of such voting takes place in several steps. For example, if there are five voters with $m_1 = 1$, $m_2 = 2$, $m_3 = 2$, $m_4 = 4$, $m_5 = 5$, then you can buy the vote of the fifth voter, and eventually everyone will vote for you. Set of people voting for you will change as follows: ${5} \rightarrow {1, 5} \rightarrow {1, 2, 3, 5} \rightarrow {1, 2, 3, 4, 5}$.
#
# Calculate the minimum number of coins you have to spend so that everyone votes for you.
#
#
# -----Input-----
#
# ...
